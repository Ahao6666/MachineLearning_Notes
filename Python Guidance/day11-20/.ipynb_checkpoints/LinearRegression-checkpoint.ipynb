# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
reg.intercept_
print(f"reg.coef_:", reg.coef_)
print(f"reg.intercept_:", reg.intercept_)
# Out:
# reg.coef_: [0.5 0.5]
# reg.intercept_: 2.220446049250313e-16

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit([[0, 0.2], [0, 0], [1, 1]], [0, .1, 1])
reg.coef_
reg.intercept_
print(f"reg.coef_:", reg.coef_)
print(f"reg.intercept_:", reg.intercept_)
# Out:
# reg.coef_: [0.38250951 0.31178707]
# reg.intercept_: 0.11444866920152097
